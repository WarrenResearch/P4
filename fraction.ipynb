# %%
from fraction_driver import AzuraFC61

# %%
collector = AzuraFC61()
collector.connect()
# Out:
# Connected to Azura FC61 at 169.254.56.105:10001

# %%
collector.identify()
# Out:
# 'IDENTIFY:8,Knauer,FC6.1,FUA251000002,1.18.000.0000,0,801,-1,-1,-1,-1,-1,-1'

# %%
collector.get_status()
# Out:
# 'STATUS:33231688,2,0,0,0,0,0,7,1,7,A7,0,1,1184,0,75648,15592,1561,29389,29400,1250,201,-1,330480,0'

# %%
collector.position()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 collector.position()
#
# File c:\Users\P4\projects\p3_sdl\fraction_driver.py:84, in AzuraFC61.position(self)
#      82 output = self._send_command("get_status")
#      83 parts = output.replace("STATUS:","").split(",")
# ---> 84 position = parts[7]
#      85 return position
#
# IndexError: list index out of range

# %%
collector.move_to_vial('a7')
# Out:
# 'OK'

# %%
collector.get_status()
# Out:
# 'STATUS:24651001,2,0,0,0,0,0,7,1,7,A7,0,1,1184,0,75648,15592,1561,29389,29400,1250,201,1,340240,0'

# %%
collector.set_remote(0)
# Out:
# 'OK'

# %%
collector.disconnect()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\P4\projects\p3_sdl\fraction_driver.py:34, in AzuraFC61._send_command(self, command)
#      33 full_command = f"{command}\r".encode('ascii')
# ---> 34 self.sock.sendall(full_command)
#      35 return self.sock.recv(4096).decode('ascii').strip()
#
# OSError: [WinError 10038] An operation was attempted on something that is not a socket
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 collector.disconnect()
#
# File c:\Users\P4\projects\p3_sdl\fraction_driver.py:23, in AzuraFC61.disconnect(self)
#      21 def disconnect(self):
#      22     """Closes the connection."""
# ---> 23     self.set_local()  # Ensure we return to LOCAL mode before disconnecting
#      24     if self.sock:
#      25         self.sock.close()
#
# File c:\Users\P4\projects\p3_sdl\fraction_driver.py:55, in AzuraFC61.set_local(self)
#      53 def set_local(self):
#      54     """Unlocks GUI keyboard and returns to LOCAL mode[cite: 456]."""
# ---> 55     return self._send_command("LOCAL")
#
# File c:\Users\P4\projects\p3_sdl\fraction_driver.py:39, in AzuraFC61._send_command(self, command)
#      36 except OSError as e:
#      37     # This catches [WinError 10038] and other socket-level deaths
#      38     self.sock = None # Clear the broken socket
# ---> 39     raise ConnectionError(f"Communication link lost: {e}")
#
# ConnectionError: Communication link lost: [WinError 10038] An operation was attempted on something that is not a socket
