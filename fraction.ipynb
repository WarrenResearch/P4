# %%
from fraction_driver import AzuraFC61

# %%
collector = AzuraFC61()
collector.connect()
# Out:
# Connected to Azura FC61 at 169.254.56.105:10001

# %%
collector.sample(5)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 collector.sample(5)
#
# File u:\projects\P3_SDL\fraction_driver.py:89, in AzuraFC61.sample(self, duration)
#      83 def sample(self, duration):
#      84     """
#      85     Collects a sample for a specified duration (in seconds).
#      86     If position is provided, moves to that position before collecting.
#      87     """
# ---> 89     self.move_next(collect_mode=0)  # Move to the next position without collecting
#      90     time.sleep(1)  # Wait for the move to complete
#      91     self.set_collect(1)  # Start collecting
#
# File u:\projects\P3_SDL\fraction_driver.py:73, in AzuraFC61.move_next(self, collect_mode)
#      71 def move_next(self, collect_mode=2):
#      72     """Moves to the next position in the sequence[cite: 133]."""
# ...

# %%
collector.set_remote()
# Out:
# 'OK'
