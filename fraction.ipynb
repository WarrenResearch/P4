# %%
from fraction_driver import AzuraFC61

# %%
collector = AzuraFC61()
collector.connect()
# Out:
# Connected to Azura FC61 at 169.254.56.105:10001

# %%
collector.identify()
# Out:
# 'IDENTIFY:8,Knauer,FC6.1,FUA251000002,1.18.000.0000,0,801,-1,-1,-1,-1,-1,-1'

# %%
collector.get_status()
# Out:
# 'STATUS:2024040,2,0,0,0,0,-1,0,0,0,Home,0,1,28205,0,126190,-73007,14296,3145,3159,-160,-159,-1,384140,0'

# %%
collector.position('w')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 collector.position('w')
#
# TypeError: position() takes 1 positional argument but 2 were given

# %%
collector.move_to_vial('w')
# Out:
# 'OK'

# %%
collector.get_status()
# Out:
# 'STATUS:4604018,2,0,0,0,0,801,1,1,100,W,1,0,64052,0,159416,77582,22668,47760,47760,2604,-185,1,398780,0'

# %%
collector.set_remote(0)
# Out:
# 'OK'

# %%
collector.disconnect()
# Out:
# Disconnected from Azura FC61 at 169.254.56.105:10001

# %%
collector.drop_count()
# Out:
# '67'

# %%
from time import sleep


print(collector.drop_count())
collector.set_collect(1)
sleep(5)
collector.set_collect(0)
print(collector.drop_count())
# Out:
# 71
# 74

# %%
collector.set_collect(1)
